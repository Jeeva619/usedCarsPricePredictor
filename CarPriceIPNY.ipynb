# %%
from google.colab import files

# Choose the file to upload
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57080869-718b-44be-beb3-17e632b7b608" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57080869-718b-44be-beb3-17e632b7b608">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df = pd.read_csv('train.csv', index_col=0)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6            Nissan Micra Diesel XV      Jaipur  2013              86999
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First    13 km/kg  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461 CC   63.1 bhp    5.0
#
#    New_Price  Price
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# ...

# %%
df.shape
# Out:
# (5847, 13)

# %%
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
df = df.drop('New_Price', axis=1)

# %%
df = df.dropna()

# %%
#replacing CC to ""
df['Engine'] = df.Engine.apply(lambda x: x.replace(' CC', ''))
df['Engine'] = df.Engine.astype(float)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6            Nissan Micra Diesel XV      Jaipur  2013              86999
#
#   Fuel_Type Transmission Owner_Type     Mileage  Engine      Power  Seats  \
# 1    Diesel       Manual      First  19.67 kmpl  1582.0  126.2 bhp    5.0
# 2    Petrol       Manual      First    13 km/kg  1199.0   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248.0  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968.0  140.8 bhp    5.0
# 6    Diesel       Manual      First  23.08 kmpl  1461.0   63.1 bhp    5.0
#
#    Price
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74
# 6   3.50

# %%
#replacing bhp to ""
df['Power'] = df.Power.apply(lambda x: x.replace(' bhp', ''))
df['Power'] = df.Power.astype(float)
df.head()

# %%
# replacing kmpl and km/kg to ""
def process_mileage(mileage):

    if mileage.endswith(' kmpl'):
        mileage = mileage.replace(' kmpl', '')
        return float(mileage)

    elif mileage.endswith(' km/kg'):
        mileage = mileage.replace(' km/kg', '')
        return float(mileage) * 1.4

df['Mileage'] = df.Mileage.apply(process_mileage)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6            Nissan Micra Diesel XV      Jaipur  2013              86999
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# 6    Diesel       Manual      First    23.08  1461.0   63.10    5.0   3.50

# %%
# instead of year we are tranforming to age
df['Age'] = df.Year.apply(lambda x: 2023 - x)
df = df.drop('Year', axis=1)
df.head()
# Out:
#                                Name    Location  Kilometers_Driven Fuel_Type  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune              41000    Diesel
# 2                      Honda Jazz V     Chennai              46000    Petrol
# 3                 Maruti Ertiga VDI     Chennai              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore              40670    Diesel
# 6            Nissan Micra Diesel XV      Jaipur              86999    Diesel
#
#   Transmission Owner_Type  Mileage  Engine   Power  Seats  Price  Age
# 1       Manual      First    19.67  1582.0  126.20    5.0  12.50    8
# 2       Manual      First    18.20  1199.0   88.70    5.0   4.50   12
# 3       Manual      First    20.77  1248.0   88.76    7.0   6.00   11
# 4    Automatic     Second    15.20  1968.0  140.80    5.0  17.74   10
# 6       Manual      First    23.08  1461.0   63.10    5.0   3.50   10

# %%
df.Fuel_Type.value_counts()
# Out:
# Diesel    3152
# Petrol    2655
# Name: Fuel_Type, dtype: int64

# %%
df.Transmission.value_counts()
# Out:
# Manual       4105
# Automatic    1702
# Name: Transmission, dtype: int64

# %%
# one hate encoding
df = pd.get_dummies(df, columns=['Fuel_Type', 'Transmission'])
df.head()
# Out:
#                                Name    Location  Kilometers_Driven Owner_Type  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune              41000      First
# 2                      Honda Jazz V     Chennai              46000      First
# 3                 Maruti Ertiga VDI     Chennai              87000      First
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore              40670     Second
# 6            Nissan Micra Diesel XV      Jaipur              86999      First
#
#    Mileage  Engine   Power  Seats  Price  Age  Fuel_Type_Diesel  \
# 1    19.67  1582.0  126.20    5.0  12.50    8                 1
# 2    18.20  1199.0   88.70    5.0   4.50   12                 0
# 3    20.77  1248.0   88.76    7.0   6.00   11                 1
# 4    15.20  1968.0  140.80    5.0  17.74   10                 1
# 6    23.08  1461.0   63.10    5.0   3.50   10                 1
#
#    Fuel_Type_Petrol  Transmission_Automatic  Transmission_Manual
# ...

# %%
df['Prev_Owners'] = df.Owner_Type.map({'First':1, 'Second':2})
df['Prev_Owners'] = df.Prev_Owners.fillna(3)
df['Prev_Owners'] = df.Prev_Owners.astype(int)
df = df.drop('Owner_Type', axis=1)
df.head()
# Out:
#                                Name    Location  Kilometers_Driven  Mileage  \
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune              41000    19.67
# 2                      Honda Jazz V     Chennai              46000    18.20
# 3                 Maruti Ertiga VDI     Chennai              87000    20.77
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore              40670    15.20
# 6            Nissan Micra Diesel XV      Jaipur              86999    23.08
#
#    Engine   Power  Seats  Price  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 1  1582.0  126.20    5.0  12.50    8                 1                 0
# 2  1199.0   88.70    5.0   4.50   12                 0                 1
# 3  1248.0   88.76    7.0   6.00   11                 1                 0
# 4  1968.0  140.80    5.0  17.74   10                 1                 0
# 6  1461.0   63.10    5.0   3.50   10                 1                 0
#
#    Transmission_Automatic  Transmission_Manual  Prev_Owners
# ...

# %%
df.Location.value_counts()
# Out:
# Mumbai        757
# Hyderabad     709
# Kochi         637
# Coimbatore    629
# Pune          581
# Delhi         535
# Kolkata       521
# Chennai       474
# Jaipur        400
# Bangalore     347
# Ahmedabad     217
# Name: Location, dtype: int64

# %%
df = df.drop('Location', axis=1)
df.head()
# Out:
#                                Name  Kilometers_Driven  Mileage  Engine  \
# 1  Hyundai Creta 1.6 CRDi SX Option              41000    19.67  1582.0
# 2                      Honda Jazz V              46000    18.20  1199.0
# 3                 Maruti Ertiga VDI              87000    20.77  1248.0
# 4   Audi A4 New 2.0 TDI Multitronic              40670    15.20  1968.0
# 6            Nissan Micra Diesel XV              86999    23.08  1461.0
#
#     Power  Seats  Price  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 1  126.20    5.0  12.50    8                 1                 0
# 2   88.70    5.0   4.50   12                 0                 1
# 3   88.76    7.0   6.00   11                 1                 0
# 4  140.80    5.0  17.74   10                 1                 0
# 6   63.10    5.0   3.50   10                 1                 0
#
#    Transmission_Automatic  Transmission_Manual  Prev_Owners
# 1                       0                    1            1
# ...

# %%
df = df.drop('Name', axis=1)
df.head()
# Out:
#    Kilometers_Driven  Mileage  Engine   Power  Seats  Price  Age  \
# 1              41000    19.67  1582.0  126.20    5.0  12.50    8
# 2              46000    18.20  1199.0   88.70    5.0   4.50   12
# 3              87000    20.77  1248.0   88.76    7.0   6.00   11
# 4              40670    15.20  1968.0  140.80    5.0  17.74   10
# 6              86999    23.08  1461.0   63.10    5.0   3.50   10
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 1                 0                       0
# 4                 1                 0                       1
# 6                 1                 0                       0
#
#    Transmission_Manual  Prev_Owners
# 1                    1            1
# 2                    1            1
# 3                    1            1
# 4                    0            2
# ...

# %%
df.shape
# Out:
# (5807, 12)

# %%
X = df.drop('Price', axis=1)
y = df.Price

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, y_pred)
# Out:
# 2.090578026391279

# %%
y_test
# Out:
# 524     37.56
# 3288     2.45
# 4111     2.55
# 4438     3.50
# 5082    31.00
#         ...
# 2154     5.49
# 3029    14.23
# 4956    33.64
# 632     29.50
# 3303     3.30
# Name: Price, Length: 1162, dtype: float64

# %%
y_pred.shape
# Out:
# (1162,)

# %%
X_train
# Out:
#       Kilometers_Driven  Mileage  Engine  Power  Seats  Age  Fuel_Type_Diesel  \
# 4581             105000    17.32  1968.0  150.0    5.0   10                 1
# 5727              30733    20.68  1995.0  190.0    5.0    5                 1
# 4307              44000    16.00  2179.0  140.0    7.0   10                 1
# 2975              32500    21.10  1197.0   85.8    5.0    9                 0
# 4871              71000    13.10  2499.0  141.0    7.0   12                 1
# ...                 ...      ...     ...    ...    ...  ...               ...
# 3923             110000    13.20  1495.0   94.0    5.0   19                 0
# 5380              85155    17.00  1197.0   80.0    5.0   13                 0
# 5415              42000    22.00  1197.0   81.8    5.0    6                 0
# 5585              47883    26.21  1248.0   88.5    5.0    8                 1
# 894              131000    10.50  2609.0  120.0    7.0   15                 1
#
# ...

# %%
mse_numpy = np.mean((y_test - y_pred)**2)

# %%
mse_numpy
# Out:
# 24.593381901415185

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y_test, y_pred)

# %%
r_squared
# Out:
# 0.782412249373781

# %%
n = len(y_test)  # number of samples
k = X_train.shape[1]  # number of predictors

adjusted_r_squared = 1 - ((1 - r_squared) * (n - 1) / (n - k - 1))

# %%
adjusted_r_squared
# Out:
# 0.7803309752373563

# %%
import pickle

# %%
pickle.dump(model,open("CarPricePredictor.pkl",'wb'))

# %%
files.download('CarPricePredictor.pkl')
